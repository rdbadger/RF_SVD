# %% [markdown]
# ## E503 Project Primer Code

# %%
import os
import itertools
from sklearn.utils import shuffle
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as d
import torch.optim as optim
import torch.nn.functional as F
import torch.nn.modules as mod
import torch.utils.data
import torch.utils.data as data
from torch.nn.utils.rnn import pack_padded_sequence
from torch.nn.utils.rnn import pad_packed_sequence
from torch.autograd import Variable
import numpy as np
import sys
import importlib
import time
import matplotlib.pyplot as plt
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image
import librosa
from scipy import signal
from scipy import stats
from scipy.special import comb
import matplotlib.pyplot as plt
import glob
import pickle
from random import randint, choice
import random
global GPU
GPU = 0
plt.style.use('default')
device = torch.device('cuda:0')
print('Torch version =', torch.__version__, 'CUDA version =', torch.version.cuda)
print('CUDA Device:', device)
print('Is cuda available? =',torch.cuda.is_available())
# Out:
# Torch version = 1.6.0 CUDA version = 10.2
# CUDA Device: cuda:0
# Is cuda available? = True

# %%
#%matplotlib notebook
# %matplotlib inline

# %% [markdown]
# #### Machine paths

# %%
path = "/home/david/sigMF_ML/SVD/" # ACE
path_save = "/home/david/sigMF_ML/SVD/svd_plots" # ACE
path_save2 = "/home/david/sigMF_ML/SVD/clean_speech/IQ_files/stoi_save/" # ace
print(path)
# Out:
# /home/david/sigMF_ML/SVD/

# %%
os.chdir(path)
db = np.fromfile("UHF_NFM_VX8_dtmf2_snr_hi.sigmf-data", dtype="float32")

# %%
n=2
I = db[0::2]
Q = db[1::2]

# %%
from timeit import default_timer as timer

# %% [markdown]
# ### scipy method

# %%
n_fft = 1024
t = len(db)
max = 5000000
db2 = db[0::]
start = timer()
db2 = db2.astype(np.float32).view(np.complex64)
Fs = 1e6
I_t, I_f, Z = signal.stft(db2, fs=Fs, nperseg=n_fft, return_onesided=False)
ps = np.abs(Z)
IQ2 = np.vstack([ps[n_fft//2:], ps[:n_fft//2]])
end = timer()
print(end - start)
# Out:
# 0.25544797699876653

# %% [markdown]
# ### SVD

# %%
U, D, V = np.linalg.svd(IQ2[:,:])

# %%
U.shape, D.shape, V.shape, IQ2.shape
# Out:
# ((1024, 1024), (1024,), (9767, 9767), (1024, 9767))

# %%
def RelativeError(A, k, U, D, V):
    A_k = np.matrix(U[:, :k]) * np.diag(D[:k]) * V[:k, :10000]
    Ak_norm = np.linalg.norm(A_k, ord=None)
#     print('Ak norm = ', Ak_norm)
    A_norm = np.linalg.norm(A, ord=None)
#     print('A_norm = ', A_norm)
    AK = np.linalg.norm((A-A_k), ord=None)
    error = AK/A_norm*100
    return error

# %% [markdown]
# ### Trying to match up vectors...

# %%
rank = np.size(IQ2[:,:10000],1)
rank
# Out:
# 9767

# %%
start = timer()
rank = np.size(IQ2[:,:10000],1)
err = np.zeros(rank) # for starting at index position 1
for k in range(1,999):
    err[k] = RelativeError(IQ2[:1024,:9767], k, U, D, V)
end = timer()
print(end - start)
# Out:
# 144.66573647399855

# %%
rank = np.size(IQ2,1)
rank = 30 # reduced rank by 1 for matrix math to work out
x = np.arange(rank+1) # Start at index position 1
f = np.argmin(err[1:rank]<1.0)
plt.figure(figsize=(9, 6))
# fig,ax = plt.subplots()
fig2 = plt.figure()
plt.scatter(x[1:rank],err[1:rank],c='r', label='error')
plt.legend(loc='upper right')
plt.title('Percent Error vs K')
plt.xlabel('k')
plt.ylabel('% Error')
plt.ylim([0, np.amax(err)+np.amax(err)*.2])
plt.xlim(0, rank-.9)
# plt.xlim(25, 30)
plt.grid()
fig2.savefig('ptt_1MSPS_ace_30vectors.png', format="png")
plt.show()
end = timer()

# %%
os.chdir(path_save)
np.save('ptt_err', err)

# %% [markdown]
# ### Find the first Ak when the realative error is less than 1%

# %%
err5 = err[1:-1]
h = np.argmax(err2<5.00)
print('Error less than 5% is', err5[h], 'at position', h, 'in the matrix.')
# Out:
# Error less than 5% is 4.126238077878952 at position 6 in the matrix.

# %%
err2 = err[1:-1]
h = np.argmax(err2<1.00)
print('Error less than 1% is', err2[h], 'at position', h, 'in the matrix.')
# Out:
# Error less than 1% is 0.7841713726520538 at position 13 in the matrix.

# %%
h = 14
print('Error at specific vector count', err2[h], 'at position', h, 'in the matrix.')
# Out:
# Error at specific vector count 0.5794023629277945 at position 14 in the matrix.

# %%
rank = np.linalg.matrix_rank(IQ2[:,1400:2500], tol=None)
print('The rank is', rank)
# Out:
# The rank is 26

# %% [markdown]
# ### Plot reconstruction up to Ak

# %%
h = 2 # new value to plot to
Ak = np.matrix(U[:, :h]) * np.diag(D[:h]) * np.matrix(V[:h, :])
plt.figure(figsize=(9, 6))
fig3 = plt.figure()
# plt.imshow(20*np.log10(np.abs(Ak)+1e-8), aspect='auto', origin='lower')
plt.imshow(20*np.log10(np.abs(Ak[700:730,2575:2850])+1e-8), aspect='auto', origin='lower')
# plt.imshow(reconstimg, cmap='gray')
# title = "UDV Vectors: k = %s" % h
# plt.title(title)
plt.xlabel('Time in seconds', fontsize=20)
plt.ylabel('Frequency in Hertz', fontsize=20)
plt.minorticks_on()
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
plt.tight_layout()
# plt.yticks(np.arange(0,30, 2))
fig3.savefig('ptt_2vectors.pdf', format="pdf")
plt.show()

# %% [markdown]
# #### Plot full reconstruction using full rank

# %%
rank = 15
Ak = np.matrix(U[:, :rank]) * np.diag(D[:rank]) * np.matrix(V[:rank, :])
plt.figure(figsize=(9, 6))
fig4 = plt.figure()
# plt.imshow(20*np.log10(np.abs(full_rank)+1e-8), aspect='auto', origin='lower')
plt.imshow(20*np.log10(np.abs(Ak[700:730,2575:2850])+1e-8), aspect='auto', origin='lower')
# title = "UDV Vectors: k = %s" % rank
# plt.title(title)
plt.xlabel('Time in seconds', fontsize=20)
plt.ylabel('Frequency in Hertz', fontsize=20)
plt.minorticks_on()
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
plt.tight_layout()
# plt.yticks(np.arange(0,30, 2))
fig4.savefig('ptt_15vectors.pdf', format="pdf")
plt.show()

# %%
rank = 1024
Ak = np.matrix(U[:, :rank]) * np.diag(D[:rank]) * np.matrix(V[:rank, :])
plt.figure(figsize=(9, 6))
fig5 = plt.figure()
# plt.imshow(20*np.log10(np.abs(full_rank)+1e-8), aspect='auto', origin='lower')
plt.imshow(20*np.log10(np.abs(Ak[700:730,2575:2850])+1e-8), aspect='auto', origin='lower')
# title = "UDV Vectors: k = %s" % rank
# plt.title(title)
plt.xlabel('Time in seconds', fontsize=20)
plt.ylabel('Frequency in Hertz', fontsize=20)
plt.minorticks_on()
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
plt.tight_layout()
# plt.yticks(np.arange(0,30, 2))
fig5.savefig('ptt_1024vectors.pdf', format="pdf")
plt.show()

# %%
plt.figure(figsize=(9, 6))
fig5 = plt.figure()
# plt.imshow(20*np.log10(np.abs(full_rank)+1e-8), aspect='auto', origin='lower')
plt.imshow(20*np.log10(np.abs(IQ2[700:730,2575:2850])+1e-8), aspect='auto', origin='lower')
# title = "UDV Vectors: k = %s" % rank
# plt.title(title)
plt.xlabel('Time in seconds', fontsize=20)
plt.ylabel('Frequency in Hertz', fontsize=20)
plt.minorticks_on()
plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
plt.tight_layout()
# plt.yticks(np.arange(0,30, 2))
fig5.savefig('ptt_original.pdf', format="pdf")
plt.show()
